# %% [markdown]
# <a href="https://colab.research.google.com/github/Opalinsky/Data-Puzzle/blob/main/Data_Puzzle_Earth's_PSA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Intro
#
# Here's is the message from Earth:
# 'I remember that if you sort the countries (or dependencies) [Guinea, Iran, Trinidad And Tobago, Honduras, Lebanon, Ethiopia, Niger, Afghanistan, India, American Samoa, Cuba, Gabon, Nicaragua, Channel Islands, Martinique] by density of population (DESCENDING) and then only look at the first letter of each country, you'll get my message back!! Can you help me please?'
#
# To help our planet, we preloaded world population and geographical data from the website Worldometer (https://worldometers.info/). Use it to do what the earth says and decode the message!

# %%
import pandas as pd

countries = ['Guinea', 'Iran', 'Trinidad and Tobago', 'Honduras', 'Lebanon',
             'Ethiopia', 'Niger', 'Afghanistan', 'India', 'American Samoa',
             'Cuba', 'Gabon', 'Nicaragua', 'Channel Islands', 'Martinique']

country_pop = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/misc/earth/population_by_country.csv')

# %%
country_pop.head()
# Out:
#   Country (or dependency)  Population (2020) Yearly Change Urban Pop %  \
# 0                   China         1440297825        0.39 %        61 %
# 1                   India         1382345085        0.99 %        35 %
# 2           United States          331341050        0.59 %        83 %
# 3               Indonesia          274021604        1.07 %        56 %
# 4                Pakistan          221612785        2.00 %        35 %
#
#   World Share
# 0     18.47 %
# 1     17.70 %
# 2      4.25 %
# 3      3.51 %
# 4      2.83 %

# %%
country_surface = pd.read_csv('https://raw.githubusercontent.com/hyperc54/data-puzzles-assets/master/misc/earth/surface_by_country.csv')

# %%
country_surface.head()
# Out:
#   Country (or dependency)  Land Area (Km²)
# 0                   China          9388211
# 1                   India          2973190
# 2           United States          9147420
# 3               Indonesia          1811570
# 4                Pakistan           770880

# %%
#using merge to do sql join on a column called Country..
country = pd.merge(country_surface, country_pop, on='Country (or dependency)')
country
# Out:
#     Country (or dependency)  Land Area (Km²)  Population (2020) Yearly Change  \
# 0                     China          9388211         1440297825        0.39 %
# 1                     India          2973190         1382345085        0.99 %
# 2             United States          9147420          331341050        0.59 %
# 3                 Indonesia          1811570          274021604        1.07 %
# 4                  Pakistan           770880          221612785        2.00 %
# ..                      ...              ...                ...           ...
# 230              Montserrat              100               4993        0.06 %
# 231        Falkland Islands            12170               3497        3.05 %
# 232                    Niue              260               1628        0.68 %
# 233                 Tokelau               10               1360        1.27 %
# 234                Holy See                0                801        0.25 %
#
#     Urban Pop % World Share
# 0          61 %     18.47 %
# 1          35 %     17.70 %
# 2          83 %      4.25 %
# 3          56 %      3.51 %
# 4          35 %      2.83 %
# ..          ...         ...
# 230        10 %      0.00 %
# 231        66 %      0.00 %
# 232        46 %      0.00 %
# 233         0 %      0.00 %
# 234        N.A.      0.00 %
#
# [235 rows x 6 columns]

# %%
#filtering countries based on the list countries
filtered_countries = country[country["Country (or dependency)"].isin(countries)]
filtered_countries
# Out:
#     Country (or dependency)  Land Area (Km²)  Population (2020) Yearly Change  \
# 1                     India          2973190         1382345085        0.99 %
# 11                 Ethiopia          1000000          115434444        2.57 %
# 17                     Iran          1628550           84176929        1.30 %
# 36              Afghanistan           652860           39074280        2.33 %
# 55                    Niger          1266700           24346468        3.84 %
# 74                   Guinea           245720           13191279        2.83 %
# 82                     Cuba           106440           11325391       -0.06 %
# 91                 Honduras           111890            9931333        1.63 %
# 108                 Lebanon            10230            6819976       -0.44 %
# 109               Nicaragua           120340            6638075        1.21 %
# 145                   Gabon           257670            2234448        2.45 %
# 153     Trinidad and Tobago             5130            1400283        0.32 %
# 178              Martinique             1060             375213       -0.08 %
# 189         Channel Islands              190             174140        0.93 %
# 209          American Samoa              200              55169       -0.22 %
#
#     Urban Pop % World Share
# 1          35 %     17.70 %
# 11         21 %      1.47 %
# 17         76 %      1.08 %
# 36         25 %      0.50 %
# 55         17 %      0.31 %
# 74         39 %      0.17 %
# 82         78 %      0.15 %
# 91         57 %      0.13 %
# 108        78 %      0.09 %
# 109        57 %      0.08 %
# 145        87 %      0.03 %
# 153        52 %      0.02 %
# 178        92 %      0.00 %
# 189        30 %      0.00 %
# 209        88 %      0.00 %

# %%
#adding Population density column
filtered_countries['Population density (person/km2)']=filtered_countries['Population (2020)']/filtered_countries['Land Area (Km²)']
filtered_countries
# Out:
# <ipython-input-40-1cd788e38c98>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_countries['Population density (person/km2)']=filtered_countries['Population (2020)']/filtered_countries['Land Area (Km²)']
#     Country (or dependency)  Land Area (Km²)  Population (2020) Yearly Change  \
# 1                     India          2973190         1382345085        0.99 %
# 11                 Ethiopia          1000000          115434444        2.57 %
# 17                     Iran          1628550           84176929        1.30 %
# 36              Afghanistan           652860           39074280        2.33 %
# 55                    Niger          1266700           24346468        3.84 %
# 74                   Guinea           245720           13191279        2.83 %
# 82                     Cuba           106440           11325391       -0.06 %
# 91                 Honduras           111890            9931333        1.63 %
# 108                 Lebanon            10230            6819976       -0.44 %
# 109               Nicaragua           120340            6638075        1.21 %
# 145                   Gabon           257670            2234448        2.45 %
# 153     Trinidad and Tobago             5130            1400283        0.32 %
# 178              Martinique             1060             375213       -0.08 %
# 189         Channel Islands              190             174140        0.93 %
# 209          American Samoa              200              55169       -0.22 %
#
#     Urban Pop % World Share  Population density (person/km2)
# 1          35 %     17.70 %                       464.936679
# 11         21 %      1.47 %                       115.434444
# 17         76 %      1.08 %                        51.688268
# 36         25 %      0.50 %                        59.850933
# 55         17 %      0.31 %                        19.220390
# 74         39 %      0.17 %                        53.684189
# 82         78 %      0.15 %                       106.401644
# 91         57 %      0.13 %                        88.759791
# 108        78 %      0.09 %                       666.664321
# 109        57 %      0.08 %                        55.161002
# 145        87 %      0.03 %                         8.671743
# 153        52 %      0.02 %                       272.959649
# 178        92 %      0.00 %                       353.974528
# 189        30 %      0.00 %                       916.526316
# 209        88 %      0.00 %                       275.845000

# %%
#sorting desc
filtered_countries_sorted = filtered_countries.sort_values(by='Population density (person/km2)',ascending=False)
filtered_countries_sorted
# Out:
#     Country (or dependency)  Land Area (Km²)  Population (2020) Yearly Change  \
# 189         Channel Islands              190             174140        0.93 %
# 108                 Lebanon            10230            6819976       -0.44 %
# 1                     India          2973190         1382345085        0.99 %
# 178              Martinique             1060             375213       -0.08 %
# 209          American Samoa              200              55169       -0.22 %
# 153     Trinidad and Tobago             5130            1400283        0.32 %
# 11                 Ethiopia          1000000          115434444        2.57 %
# 82                     Cuba           106440           11325391       -0.06 %
# 91                 Honduras           111890            9931333        1.63 %
# 36              Afghanistan           652860           39074280        2.33 %
# 109               Nicaragua           120340            6638075        1.21 %
# 74                   Guinea           245720           13191279        2.83 %
# 17                     Iran          1628550           84176929        1.30 %
# 55                    Niger          1266700           24346468        3.84 %
# 145                   Gabon           257670            2234448        2.45 %
#
#     Urban Pop % World Share  Population density (person/km2)
# 189        30 %      0.00 %                       916.526316
# 108        78 %      0.09 %                       666.664321
# 1          35 %     17.70 %                       464.936679
# 178        92 %      0.00 %                       353.974528
# 209        88 %      0.00 %                       275.845000
# 153        52 %      0.02 %                       272.959649
# 11         21 %      1.47 %                       115.434444
# 82         78 %      0.15 %                       106.401644
# 91         57 %      0.13 %                        88.759791
# 36         25 %      0.50 %                        59.850933
# 109        57 %      0.08 %                        55.161002
# 74         39 %      0.17 %                        53.684189
# 17         76 %      1.08 %                        51.688268
# 55         17 %      0.31 %                        19.220390
# 145        87 %      0.03 %                         8.671743

# %%
#getting the mesagge
message = filtered_countries_sorted['Country (or dependency)']
message = message.str.get(0)
# Out:
# 189    C
# 108    L
# 1      I
# 178    M
# 209    A
# 153    T
# 11     E
# 82     C
# 91     H
# 36     A
# 109    N
# 74     G
# 17     I
# 55     N
# 145    G
# Name: Country (or dependency), dtype: object
